# %% [markdown]
# # 02 Baseline Evaluation
# Compute baseline extraction metrics before LoRA fine-tuning.

# %%
from src.evaluation.metrics import compute_exact_match, compute_f1

pred = "invoice total 19.99"
ref = "invoice total 19.99"
print(compute_exact_match(pred, ref), compute_f1(pred, ref))
