# %% [markdown]
# # 04 Results Comparison
# Sort and compare multiple run scores.

# %%
from src.evaluation.compare import compare_runs

scores = {"baseline": 0.71, "lora_run_1": 0.78, "lora_run_2": 0.80}
print(compare_runs(scores))
