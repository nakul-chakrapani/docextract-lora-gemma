# %% [markdown]
# # 03 Training Runs
# Load YAML configs and invoke the training stub.

# %%
from pathlib import Path
from src.training.train import build_configs

root = Path.cwd().parent
lora_cfg, train_cfg = build_configs(root / "configs/lora_config.yaml", root / "configs/training_config.yaml")
print(lora_cfg)
print(train_cfg)
