# %% [markdown]
# # 05 VRDU Generalization
# Evaluate transfer from CORD-tuned adapters to VRDU-like data.

# %%
from src.data.dataset import load_vrdu

vrdu_eval = load_vrdu(split="validation", dataset_name="vrdu")
print(vrdu_eval)
